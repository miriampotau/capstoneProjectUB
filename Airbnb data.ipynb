# %%
import pandas as pd

dataBcn = pd.read_csv('Data_Bcn/Barcelona_210412/calendar.csv')
dataMov = pd.read_csv('Mobilidad_Espanya/20200317_matriz_mitma.csv',sep='|')
dataCovCat = pd.read_csv('catalunya_setmanal_total_pob.csv', sep = ';')
Bcn2104 = pd.read_csv('Data_Bcn/Barcelona_210412/listings.csv')
Bcn2103 = pd.read_csv('Data_Bcn/Barcelona_210305/listings.csv')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              id                            listing_url       scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  20210409161549
# 1         20168     https://www.airbnb.com/rooms/20168  20210409161549
# 2         25428     https://www.airbnb.com/rooms/25428  20210409161549
# 3         27886     https://www.airbnb.com/rooms/27886  20210409161549
# 4         28871     https://www.airbnb.com/rooms/28871  20210409161549
# ...         ...                                    ...             ...
# 17820  49085366  https://www.airbnb.com/rooms/49085366  20210409161549
# 17821  49089176  https://www.airbnb.com/rooms/49089176  20210409161549
# 17822  49101225  https://www.airbnb.com/rooms/49101225  20210409161549
# 17823  49102514  https://www.airbnb.com/rooms/49102514  20210409161549
# 17824  49119460  https://www.airbnb.com/rooms/49119460  20210409161549
#
#       last_scraped                                               name  \
# ...

# %%
data.shape
# Out:
# (17825, 74)

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
dataBcn.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       18674  2021-04-13         f  $157.00        $157.00             3.0
# 1      268022  2021-04-14         f  $187.00        $187.00             1.0
# 2      268022  2021-04-15         f  $187.00        $187.00             1.0
# 3      268022  2021-04-16         f  $218.00        $218.00            32.0
# 4      268022  2021-04-17         f  $218.00        $218.00            32.0
#
#    maximum_nights
# 0          1125.0
# 1           365.0
# 2           365.0
# 3           365.0
# 4           365.0

# %%
dataBcn[dataBcn.price!=dataBcn.adjusted_price]
# Out:
#          listing_id        date available    price adjusted_price  \
# 1461         269467  2021-04-14         f   $55.00         $44.00
# 1462         269467  2021-04-15         f   $55.00         $44.00
# 1463         269467  2021-04-16         f   $55.00         $44.00
# 1464         269467  2021-04-17         f   $55.00         $44.00
# 1465         269467  2021-04-18         f   $55.00         $44.00
# ...             ...         ...       ...      ...            ...
# 6652819    49122593  2021-04-26         t  $125.00        $100.00
# 6652820    49122593  2021-04-27         t  $125.00        $100.00
# 6652821    49122593  2021-04-28         t  $125.00        $100.00
# 6652822    49122593  2021-04-29         t  $125.00        $100.00
# 6652823    49122593  2021-04-30         t  $125.00        $100.00
#
#          minimum_nights  maximum_nights
# 1461                7.0           760.0
# 1462                7.0           760.0
# 1463                7.0           760.0
# ...

# %%
dataBcn.date
# Out:
# 0          2021-04-13
# 1          2021-04-14
# 2          2021-04-15
# 3          2021-04-16
# 4          2021-04-17
#               ...
# 6653167    2022-04-09
# 6653168    2022-04-10
# 6653169    2022-04-11
# 6653170    2022-04-12
# 6653171    2022-04-13
# Name: date, Length: 6653172, dtype: object

# %%
dataMov.head(200)
# Out:
#         fecha    origen   destino  periodo distancia  viajes  viajes_km
# 0    20200317  01001_AM  01001_AM        0   002-005  37.099    127.358
# 1    20200317  01001_AM  01001_AM        0   005-010  25.995    207.804
# 2    20200317  01001_AM  01001_AM        1  0005-002   6.406     10.906
# 3    20200317  01001_AM  01001_AM        1   005-010   6.279     45.595
# 4    20200317  01001_AM  01001_AM        1   010-050  19.614    282.926
# ..        ...       ...       ...      ...       ...     ...        ...
# 195  20200317  01001_AM  01058_AM       22   010-050  25.141    306.493
# 196  20200317  01001_AM  01058_AM       23   005-010   9.393     58.949
# 197  20200317  01001_AM  01058_AM       23   010-050  13.500    141.865
# 198  20200317  01001_AM     01059        0   005-010  15.207    136.839
# 199  20200317  01001_AM     01059        0   010-050  47.490    642.282
#
# [200 rows x 7 columns]

# %%
dataCovCat.head()
# Out:
#          NOM    CODI    DATA_INI     DATA_FI  IEPG_CONFIRMAT  R0_CONFIRMAT_M  \
# 0  CATALUNYA  GLOBAL  2021-04-24  2021-04-30         264.591        0.979199
# 1  CATALUNYA  GLOBAL  2021-04-23  2021-04-29         280.583        1.018850
# 2  CATALUNYA  GLOBAL  2021-04-22  2021-04-28         290.621        1.043280
# 3  CATALUNYA  GLOBAL  2021-04-21  2021-04-27         296.883        1.054310
# 4  CATALUNYA  GLOBAL  2021-04-20  2021-04-26         300.673        1.064810
#
#        IA14  TAXA_CASOS_CONFIRMAT  CASOS_CONFIRMAT  TAXA_PCRTAR  ...  \
# 0  272.4279              130.6769            10101    2437.1160  ...
# 1  277.4474              134.9720            10433    2426.3782  ...
# 2  280.4359              137.5982            10636    2455.7712  ...
# 3  283.4243              140.3279            10847    2464.7236  ...
# 4  284.0712              143.8597            11120    2456.7285  ...
#
#    INGRESSOS_CRITIC  EXITUS  CASOS_PCR  CASOS_TAR  POSITIVITAT_PCR_NUM  \
# ...

# %%
Bcn2104
# Out:
#              id                            listing_url       scrape_id  \
# 0         18674     https://www.airbnb.com/rooms/18674  20210412154247
# 1         23197     https://www.airbnb.com/rooms/23197  20210412154247
# 2         32711     https://www.airbnb.com/rooms/32711  20210412154247
# 3         34241     https://www.airbnb.com/rooms/34241  20210412154247
# 4         34981     https://www.airbnb.com/rooms/34981  20210412154247
# ...         ...                                    ...             ...
# 18221  49155035  https://www.airbnb.com/rooms/49155035  20210412154247
# 18222  49155115  https://www.airbnb.com/rooms/49155115  20210412154247
# 18223  49155172  https://www.airbnb.com/rooms/49155172  20210412154247
# 18224  49155456  https://www.airbnb.com/rooms/49155456  20210412154247
# 18225  49158347  https://www.airbnb.com/rooms/49158347  20210412154247
#
#       last_scraped                                               name  \
# ...

# %%
Bcn2104copy = Bcn2104.copy()

# %%
Bcn2104copy.drop(['listing_url', 'scrape_id', 'name', 'description',
       'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
       'host_name', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'property_type', 'room_type', 'accommodates', 'bathrooms',
       'bathrooms_text', 'amenities',
       'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm','host_since', 'neighbourhood',
       'calendar_updated', 'review_scores_communication', 'review_scores_location', 'license', 'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'host_neighbourhood',
       'neighbourhood_cleansed', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_value', 
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'instant_bookable' ], axis=1, inplace=True)

# %%
Bcn2104copy[1:50]
# Out:
#         id last_scraped                   host_location  \
# 1    23197   2021-04-14                Catalonia, Spain
# 2    32711   2021-04-14     Barcelona, Catalonia, Spain
# 3    34241   2021-04-15     Barcelona, Catalonia, Spain
# 4    34981   2021-04-15     Barcelona, Catalonia, Spain
# 5    35379   2021-04-15      Barcelona, Cataluña, Spain
# 6    35388   2021-04-15      Barcelona, Cataluña, Spain
# 7    35390   2021-04-16      Barcelona, Cataluña, Spain
# 8    35392   2021-04-15      Barcelona, Cataluña, Spain
# 9    36763   2021-04-15      Barcelona, Cataluña, Spain
# 10   40983   2021-04-15      Barcelona, Cataluña, Spain
# 11   41952   2021-04-15      Barcelona, Cataluña, Spain
# 12   46153   2021-04-14                Catalonia, Spain
# 13   49968   2021-04-14     Barcelona, Catalonia, Spain
# 14   58512   2021-04-15  Leeds, England, United Kingdom
# 15   61444   2021-04-14                           spain
# 16   68547   2021-04-13     Barcelona, Catalonia, Spain
# ...

# %%
Bcn2103
# Out:
#              id                            listing_url       scrape_id  \
# 0         18674     https://www.airbnb.com/rooms/18674  20210305163922
# 1         21974     https://www.airbnb.com/rooms/21974  20210305163922
# 2         23197     https://www.airbnb.com/rooms/23197  20210305163922
# 3         32711     https://www.airbnb.com/rooms/32711  20210305163922
# 4         34241     https://www.airbnb.com/rooms/34241  20210305163922
# ...         ...                                    ...             ...
# 18281  48433403  https://www.airbnb.com/rooms/48433403  20210305163922
# 18282  48433703  https://www.airbnb.com/rooms/48433703  20210305163922
# 18283  48446266  https://www.airbnb.com/rooms/48446266  20210305163922
# 18284  48452514  https://www.airbnb.com/rooms/48452514  20210305163922
# 18285  48459666  https://www.airbnb.com/rooms/48459666  20210305163922
#
#       last_scraped                                               name  \
# ...
